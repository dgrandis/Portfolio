# %% [markdown]
# # Задание **Lite**
#
# Выполните задание ultra light в любом редакторе схем данных.

# %% [markdown]
# Для начала посмотрим какую информацию можно взять с данного сайта

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Есть вкладки: **Фильмы**, **сериалы**, **актеры**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Жанры фильмов и так далее

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Из этого сайта можно взять нужную информацию, чтобы составить диаграмму.

# %% [markdown]
# # ERD диаграмма - это диаграмма сущность свзяь

# %% [markdown]
# Для начала нужно определиться что имеют в своем составе сущности.

# %% [markdown]
# ## **Фильм:**
#   - Название
#   - Жанр
#   - Рейтинг
#   - Продолжительность
#   - Год выхода
#   - Бюджет
#   - Постер
#   - Обзор
#   - Кассовые сборы

# %% [markdown]
# # Каждый фильм имеет **персонажа**:
#   - Имя
#   - Актер

# %% [markdown]
# ## Каждый фильм имеет съемочный **состав**:
#  - Имя
#  - Роль в съемке

# %% [markdown]
# # Съмочный состав имеет **персонал**:
#   - Имя
#   - Род занятий

# %% [markdown]
# # **Так же Актеры**:
# - Фамилия
# - Имя
# - Род занятий
# - Фильмография
# - Биография
# - Дата рождения
# - Место рождения
# - Пол
# - Фотографии
# - Награды

# %% [markdown]
# ## **Сериал:**
#   - Название
#   - Жанр
#   - Сезоны
#   - Рейтинг
#   - Продолжительность
#   - Год выхода
#   - Бюджет
#   - Постер
#   - Обзор
#
# Так же сериал имеет сезоны:
#   - Эпизод
#   - Дата выхода
#
# И каждый сезон имеет эпизоды:
#  - Название
#  - Дата выхода
#  - Продолжительность

# %% [markdown]
# Попробуем изобрать все это на диаграмме **ERD**

# %% [markdown]
# Данная диаграмма создавалась с помощью сайта: https://www.diagrameditor.com/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Диаграмма в виде картинки в формате **png**

# %% [markdown]
# ![Ultra Lite.png](data:image/png;base64,...)

# %% [markdown]
# Диаграмма доступна по ссылке: https://drive.google.com/file/d/1bPwzf9rxMcNAD6YJiU-kHGDY7BDDylCl/view?usp=sharing
