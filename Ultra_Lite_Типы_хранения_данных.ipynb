# %% [markdown]
# # Задание **Ultra Lite**
#
# Вам требуется хранить большое количество фотографий в формате JPEG (десятки миллионов), фотографии не связаны логически и не имеют иерархии. Фотографии имеют метаданные: Дату создания и набор тэгов (один или несколько), скорость записи новых данных значения не имеет, необходимо обеспечить наиболее быструю отдачу данных, потеря данных не критична, предложите вариант СХД под данную задачу, обоснуйте выбор.

# %% [markdown]
# ![ZHurnal_setevyh_reshenij_LAN_2_(4523).png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Хорошей СДХ можно предполодить **S3** от **Amazon**.
#
#  - Как видно из скриншота выше, данная система обладает необходимыми ресурсами, которые подходят для реализации данной задачи
#
#  - Быстрые чтение и запись
#
#  - Возможность увеличить емкость для данных
#
#  - Быстрый поиск данных

# %% [markdown]
# # Так же можно использовать **Google File System (GFS)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  - Система должна хранить много больших файлов. Как правило, несколько миллионов файлов, каждый от 100 Мб и больше.
#  - Так же есть возможность увеличения пространства для хранения данных.
