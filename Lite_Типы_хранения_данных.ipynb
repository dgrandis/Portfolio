# %% [markdown]
# # Задание **Lite**
#
# В вашей организации планируется создать единый файловый сервер (размером в 10 Тб), количество пользователей оценивается в 100-200, скорость доступа к данным не имеет значения, требуется обеспечить резервирование данных (время восстановления не имеет значения), предложите вариант СХД под данную задачу.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Для данной задачи вполне подойдет Система Хранения Данных - **NAS**

# %% [markdown]
# **Network attached storage**, или сетевое файловое хранилище, представляет дисковые ресурсы в виде файлов (или объектов) с использованием сетевых протоколов
#
#  - Доступность его ресурсов не только для отдельных серверов, но и для любых компьютеров организации.
#
# - Дешевизна
#
# - Предоставление общего файлового доступа (для **100-200** возможно)
#
# - Сама система хранения может быть сколько угодно далеко от потребителей (в разумных пределах разумеется)
#
# - Редактирование файлов и изображений
#
# - Сохранность данных(нет доступа из вне)
#
# - Простота настроек и гибкость коллективного использования ресурсов.
#
# - Невозможно использовать «нефайловые» методы. Доступ к информации через протоколы «сетевых файловых систем» иногда медленнее, чем как к «локальному диску».
#   Но так как по условию скорость не важна, то данный факт можно не учитывать.

# %% [markdown]
# Так же для резервирования можно использовать **RAID**-массив

# %% [markdown]
# ![fbc6b3e27c2dacc7fab90496ba6e9282.jpeg](data:image/jpeg;base64,...)
