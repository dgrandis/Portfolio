# %% [markdown]
# # Задание **Pro**
#
# Возьмите схему данных из задания Light.
#
# Приведите таблицу Customers в 3НФ - третью Нормальную Форму (создайте дополнительные таблицы , если необходимо).
#
# Создайте полученную схему в любой программе для создания схем данных.
#
# Если используете собственную программу, приложите ссылку на нее.

# %% [markdown]
# # Приведите таблицу Customers в 3НФ - третью Нормальную Форму

# %% [markdown]
# Для этого нужно разбить ее на 3 таблицы.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **dbdesigner**

# %% [markdown]
# Данна таблица доступна по адресу: https://dbdesigner.page.link/6HavwATonAgHFqer5
