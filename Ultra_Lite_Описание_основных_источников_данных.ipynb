# %% [markdown]
# # Задание **Ultra Lite**
#
# 1. Найдите в Интернете или создайте самостоятельно 3 примера структурированных и неструктурированных данных (результат необходимо представить в виде файлов).
#
# 2. Даны 2 алгоритма. Первый алгоритм на обработку 10 записей затрачивает одну операцию. Второй алгоритм на обработку 1 записи затрачивает одну операцию. Какой алгоритм работает быстрее? Запишите алгоритмическую сложность каждого алгоритма через «О».
#
# 3. Даны 2 алгоритма. Первый алгоритм на обработку 1000 записей затрачивает 3 операции. Второй алгоритм на обработку 1000 000 записи затрачивает 6 операций. Какой алгоритм работает быстрее? Запишите алгоритмическую сложность каждого алгоритма через «О»

# %% [markdown]
# # Задание 1

# %% [markdown]
# **Структурированные данные:**
#
# 1. [Рейтинг стран мира по уровню занятости](https://gtmarket.ru/ratings/employment-ranking)
# 2. [250 лучших фильмов](https://ru.wikipedia.org/wiki/250_%D0%BB%D1%83%D1%87%D1%88%D0%B8%D1%85_%D1%84%D0%B8%D0%BB%D1%8C%D0%BC%D0%BE%D0%B2_%D0%BF%D0%BE_%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D0%B8_IMDb)
#
# 3. [Динамика курса акций ПАО Газпром (руб., MOEX)](https://yandex.ru/news/quotes/29.html)

# %% [markdown]
# **Нетруктурированные данные:**
#
# 1. [Keras: библиотека глубокого обучение на Python](https://ru-keras.com/home/)
#
# 2. [Яндекс Новости](https://yandex.ru/news)
#
# 3. [Л. Н. Толстой. Война и мир](https://ilibrary.ru/text/11/p.1/index.html)

# %% [markdown]
# # Задание 2

# %% [markdown]
# 1. Первый алгоритм работает быстрее
# 2. **O(n/10)** - для первого алгоритма
# 2. **O(n)**    - для второго алгоритма

# %% [markdown]
# # Задание 3

# %% [markdown]
# 1. Если линейная зависимость, то второй алгоритм работает быстрее
# 2. **O(n * 0.003)**    - для первого алгоритма  (три тысячных)
# 3. **O(n * 0.000006)** - для второго алгоритма  (шесть миллионных)
#
# 4. Если логарифмическая зависимость lg(десятичный логорифм), тогда оба алгоритма работают одинаково **O(lg(n))**.
#
# Так как lg(1000) = 3, а lg(1000_000) = 6
