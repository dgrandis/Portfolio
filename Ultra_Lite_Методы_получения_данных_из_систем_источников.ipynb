# %% [markdown]
# # Задание **Ultra Lite**
#
#
# **Задача 1**
#
# В PostgreSQL подключитесь к существующей базе данных "postgres"  и выведите первые 10 строк таблицы pg_amproc
#
# **Задача 2**
#
# Выведите из таблицы pg_attribute только поля: attname,attlen, attbyval
#
# Инструкция по установке  PostgreSQL: https://www.youtube.com/watch?v=oEi5IUgxaU0

# %% [markdown]
# В первую очерель была устанвовлена программа **PostgreSQL** согласно инструкции на локальный компьютер.
#
# Версия **12.11** build **1914**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Задача **1**
#
# В PostgreSQL подключитесь к существующей базе данных "postgres" и выведите первые 10 строк таблицы pg_amproc

# %%
#  Для того чтобы отобразить первые 10 строк из таблицы pg_amproc, нужно ввести следующую команду и выполнить ее

SELECT * FROM pg_amproc limit 10

# %% [markdown]
# Благодаря этой команде можно увидеть первые 10 строк данной таблицы

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Задача **2**
#
# Выведите из таблицы pg_attribute только поля: attname,attlen, attbyval

# %%
#  Данную задачу можно решить с помощью кода

SELECT attname, attlen, attbyval from pg_attribute

# %% [markdown]
# Результат работа приведен ниже

# %% [markdown]
# ![image.png](data:image/png;base64,...)
